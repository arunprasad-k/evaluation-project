# %% [markdown]
# # Program to Predict

# %% [markdown]
# ## 1)Aggregated Death case count for the state

# %% [markdown]
# ## 2)Aggregated Recovered case count for the state.

# %% [markdown]
# ### DATASET DESCRIPTION
#
#    This is the data repository for the 2019 Novel Coronavirus Visual Dashboard operated by the Johns Hopkins University Center for Systems Science and Engineering (JHU CSSE). Also, Supported by ESRI Living Atlas Team and the Johns Hopkins University Applied Physics Lab (JHU APL).
#
#    Coronavirus is a family of viruses that can cause illness, which can vary from common cold and cough to sometimes more severe disease. Middle East Respiratory Syndrome (MERS-CoV) and Severe Acute Respiratory Syndrome (SARS-CoV) were such severe cases with the world already has faced. SARS-CoV-2 (n-coronavirus) is the new virus of the coronavirus family, which first discovered in 2019, which has not been identified in humans before. It is a contiguous virus which started from Wuhan in December 2019. Which later declared as Pandemic by WHO due to high rate spreads throughout the world. Currently (on the date 20 May 2020), this leads to a total of 300K+ Deaths across the globe, including 90K+ deaths alone in USA.The dataset  is provided to identify the deaths and recovered cases.

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#loading dataframe
df=pd.read_csv("covid19.csv")
df
# Out:
#               Province_State Country_Region          Last_Update      Lat  \
# 0                    Alabama             US  2020-05-21 02:32:54  32.3182
# 1                     Alaska             US  2020-05-21 02:32:54  61.3707
# 2             American Samoa             US  2020-05-21 02:32:54 -14.2710
# 3                    Arizona             US  2020-05-21 02:32:54  33.7298
# 4                   Arkansas             US  2020-05-21 02:32:54  34.9697
# 5                 California             US  2020-05-21 02:32:54  36.1162
# 6                   Colorado             US  2020-05-21 02:32:54  39.0598
# 7                Connecticut             US  2020-05-21 02:32:54  41.5978
# 8                   Delaware             US  2020-05-21 02:32:54  39.3185
# 9           Diamond Princess             US  2020-05-21 02:32:54      NaN
# 10      District of Columbia             US  2020-05-21 02:32:54  38.8974
# 11                   Florida             US  2020-05-21 02:32:54  27.7663
# ...

# %% [markdown]
# ###### Attributes Description:
#
#     1)Province_State - The name of the State within the USA.
#
#         Province, state or dependency name.
#
#     2)Country_Region - The name of the Country (US).
#
#         Country, region or sovereignty name. The names of locations included on the Website correspond with the official designations used by the U.S. Department of State.
#
#     3)Last_Update - The most recent date the file was pushed.
#
#         MM/DD/YYYY HH:mm:ss (24 hour format, in UTC).
#
#     4)Lat - Latitude.
#
#     5)Long_ - Longitude.
#
#          Dot locations on the dashboard. All points (except for Australia) shown on the map are based on geographic centroids, and are not representative of a specific address, building or any location at a spatial scale finer than a province/state. Australian dots are located at the centroid of the largest city in each state.
#
#     6)Confirmed - Aggregated confirmed case count for the state.
#
#         Confirmed cases include presumptive positive cases and probable cases, in accordance with CDC guidelines.
#
#     7)Deaths - Aggregated Death case count for the state.
#
#          Death totals in the US include confirmed and probable, in accordance with CDC guidelines as of April 14.
#
#     8)Recovered - Aggregated Recovered case count for the state.
#
#         Recovered cases outside China are estimates based on local media reports, and state and local reporting when available, and therefore may be substantially lower than the true number.
#
#     9)Active - Aggregated confirmed cases that have not been resolved (Active = Confirmed - Recovered - Deaths).
#
#         Active cases = total confirmed - total recovered - total deaths.
#
#     10)FIPS - Federal Information Processing Standards code that uniquely identifies counties within the USA.
#
#         US only. Federal Information Processing Standards code that uniquely identifies counties within the USA.
#
#     11)Incident_Rate - confirmed cases per 100,000 persons.
#
#         Admin2 + Province_State + Country_Region.
#
#     12)People_Tested - Total number of people who have been tested.
#
#     13)People_Hospitalized - Total number of people hospitalized.
#
#     14)Mortality_Rate - Number recorded deaths * 100/ Number confirmed cases.
#
#     15)UID - Unique Identifier for each row entry.
#
#     16)ISO3 - Officialy assigned country code identifiers.
#
#     17)Testing_Rate - Total number of people tested per 100,000 persons.
#
#          total test results per 100,000 persons. The "total test results" is equal to "Total test results (Positive + Negative)" from COVID Tracking Project.
#
#     18)Hospitalization_Rate - Total number of people hospitalized * 100/ Number of confirmed cases.
#
#         Total number hospitalized / Number confirmed cases. The "Total number hospitalized" is the "Hospitalized – Cumulative" count from COVID Tracking Project. The "hospitalization rate" and "hospitalized - Cumulative" data is only presented for those states which provide cumulative hospital data.

# %% [markdown]
# # Basis Statistics

# %%
#no of rows and columns
df.shape
# Out:
# (58, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Province_State        58 non-null     object
#  1   Country_Region        58 non-null     object
#  2   Last_Update           58 non-null     object
#  3   Lat                   56 non-null     float64
#  4   Long_                 56 non-null     float64
#  5   Confirmed             58 non-null     int64
#  6   Deaths                58 non-null     int64
#  7   Recovered             42 non-null     float64
#  8   Active                58 non-null     float64
#  9   FIPS                  58 non-null     int64
#  10  Incident_Rate         56 non-null     float64
#  11  People_Tested         56 non-null     float64
#  12  People_Hospitalized   33 non-null     float64
#  13  Mortality_Rate        57 non-null     float64
#  14  UID                   58 non-null     int64
# ...

# %%
df.columns
# Out:
# Index(['Province_State', 'Country_Region', 'Last_Update', 'Lat', 'Long_',
#        'Confirmed', 'Deaths', 'Recovered', 'Active', 'FIPS', 'Incident_Rate',
#        'People_Tested', 'People_Hospitalized', 'Mortality_Rate', 'UID', 'ISO3',
#        'Testing_Rate', 'Hospitalization_Rate'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Province_State           object
# Country_Region           object
# Last_Update              object
# Lat                     float64
# Long_                   float64
# Confirmed                 int64
# Deaths                    int64
# Recovered               float64
# Active                  float64
# FIPS                      int64
# Incident_Rate           float64
# People_Tested           float64
# People_Hospitalized     float64
# Mortality_Rate          float64
# UID                       int64
# ISO3                     object
# Testing_Rate            float64
# Hospitalization_Rate    float64
# dtype: object

# %% [markdown]
# # Finding Missing Values

# %%
df.isnull().sum()
# Out:
# Province_State           0
# Country_Region           0
# Last_Update              0
# Lat                      2
# Long_                    2
# Confirmed                0
# Deaths                   0
# Recovered               16
# Active                   0
# FIPS                     0
# Incident_Rate            2
# People_Tested            2
# People_Hospitalized     25
# Mortality_Rate           1
# UID                      0
# ISO3                     0
# Testing_Rate             2
# Hospitalization_Rate    25
# dtype: int64

# %% [markdown]
# ###### Observation:
#
# We can find missing values in
#
#     Lat
#
#     Long_
#
#     Recovered
#
#     Incident Rate
#
#     People Tested
#
#     People_Hospitalized
#
#     Mortality_Rate
#
#     Testing_Rate
#
#     Hospitalization_Rate

# %% [markdown]
# # Filling Missing Values

# %%
#missing values in Recovered
df["Recovered"].isnull().sum()
# Out:
# 16

# %% [markdown]
# ###### NOTE
#
# dropping column with NaN values may lead to loss of data.
#
# since column "Recovered" has a continious value we will fill the missing data with the mean value.

# %%
df["Recovered"].mean()
# Out:
# 7007.428571428572

# %%
#Filling NaN Values
df["Recovered"].fillna(df['Recovered'].mean(),inplace=True)

# %%
#missing values in People_Hospitalized
df["People_Hospitalized"].isnull().sum()
# Out:
# 25

# %% [markdown]
# ###### NOTE
#
# dropping column with NaN values may lead to loss of data.
#
# since column "People_Hospitalized" has a continious value we will fill the missing data with the mean value.

# %%
df["People_Hospitalized"].mean()
# Out:
# 4897.454545454545

# %%
#Filling NaN Values with mean
df["People_Hospitalized"].fillna(df['People_Hospitalized'].mean(),inplace=True)

# %%
#missing values in Hospitalization_Rate
df["Hospitalization_Rate"].isnull().sum()
# Out:
# 25

# %% [markdown]
# ###### NOTE
#
# dropping column with NaN values may lead to loss of data.
#
# since column "Hospitalization_Rate" has a continious value we will fill the missing data with the mean value.

# %%
df["Hospitalization_Rate"].mean()
# Out:
# 14.342541433640415

# %%
#Filling NaN Values with mean
df["Hospitalization_Rate"].fillna(df['Hospitalization_Rate'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Province_State          0
# Country_Region          0
# Last_Update             0
# Lat                     2
# Long_                   2
# Confirmed               0
# Deaths                  0
# Recovered               0
# Active                  0
# FIPS                    0
# Incident_Rate           2
# People_Tested           2
# People_Hospitalized     0
# Mortality_Rate          1
# UID                     0
# ISO3                    0
# Testing_Rate            2
# Hospitalization_Rate    0
# dtype: int64

# %%
df.shape
# Out:
# (58, 18)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (55, 18)

# %%
df.isnull().sum()
# Out:
# Province_State          0
# Country_Region          0
# Last_Update             0
# Lat                     0
# Long_                   0
# Confirmed               0
# Deaths                  0
# Recovered               0
# Active                  0
# FIPS                    0
# Incident_Rate           0
# People_Tested           0
# People_Hospitalized     0
# Mortality_Rate          0
# UID                     0
# ISO3                    0
# Testing_Rate            0
# Hospitalization_Rate    0
# dtype: int64

# %% [markdown]
# # Exploring Attributes

# %%
df["Country_Region"].value_counts()
# Out:
# US    55
# Name: Country_Region, dtype: int64

# %% [markdown]
# ###### observation:
#
# the columnn "Country_Region" has only one value throughout the dataset so it will not help us in any way
#
# so lets drop

# %%
#dropping column Country Region
df.drop(columns=["Country_Region"],inplace=True)

# %%
df["Province_State"].value_counts()
# Out:
# New Hampshire               1
# Wyoming                     1
# Guam                        1
# Hawaii                      1
# Missouri                    1
# New York                    1
# Tennessee                   1
# Oklahoma                    1
# South Dakota                1
# Kansas                      1
# Utah                        1
# Alaska                      1
# Virginia                    1
# Arizona                     1
# Northern Mariana Islands    1
# Texas                       1
# North Dakota                1
# Indiana                     1
# California                  1
# New Jersey                  1
# Washington                  1
# Maryland                    1
# Idaho                       1
# Nebraska                    1
# Virgin Islands              1
# New Mexico                  1
# Florida                     1
# Maine                       1
# Connecticut                 1
# Georgia                     1
# West Virginia               1
# ...

# %% [markdown]
# ###### Observation:
#
#  column "Province_State" is not much useful for our program.so lets drop it

# %%
#dropping column Province_State
df.drop(columns=["Province_State"],inplace=True)

# %%
df["Last_Update"].value_counts()
# Out:
# 2020-05-21 02:32:54    55
# Name: Last_Update, dtype: int64

# %% [markdown]
# ###### Observation:
#
# the columnn "Country_Region" has only one value throughout the dataset so it will not help us in any way
#
# so lets drop

# %%
#dropping column Last_Update
df.drop(columns=["Last_Update"],inplace=True)

# %%
df["ISO3"].value_counts()
# Out:
# USA    51
# PRI     1
# VIR     1
# MNP     1
# GUM     1
# Name: ISO3, dtype: int64

# %%
#Mapping column ISO3 from Object to Integer
df["ISO3"]=df["ISO3"].map({"USA":0,"MNP":1,"VIR":2,"GUM":3,"PRI":4}).astype(int)

# %%
#Rechecking Datatypes
df.dtypes
# Out:
# Lat                     float64
# Long_                   float64
# Confirmed                 int64
# Deaths                    int64
# Recovered               float64
# Active                  float64
# FIPS                      int64
# Incident_Rate           float64
# People_Tested           float64
# People_Hospitalized     float64
# Mortality_Rate          float64
# UID                       int64
# ISO3                      int32
# Testing_Rate            float64
# Hospitalization_Rate    float64
# dtype: object

# %%
df.describe()
# Out:
#              Lat       Long_      Confirmed        Deaths     Recovered  \
# count  55.000000   55.000000      55.000000     55.000000     55.000000
# mean   37.769382  -83.662516   28212.745455   1698.836364   7007.428571
# std     8.453768   48.840127   53614.101223   4178.550115  10172.623397
# min    13.444300 -157.498300      21.000000      2.000000     13.000000
# 25%    34.905100  -99.611400    3834.500000     98.500000   1187.500000
# 50%    39.063900  -86.902300   11528.000000    407.000000   4423.000000
# 75%    42.493100  -76.914450   31172.000000   1561.500000   7007.428571
# max    61.370700  145.673900  354370.000000  28636.000000  61886.000000
#
#               Active       FIPS  Incident_Rate  People_Tested  \
# count      55.000000  55.000000      55.000000   5.500000e+01
# mean    21162.781818  32.036364     403.435002   2.299576e+05
# std     42148.607793  18.878720     402.735419   2.999399e+05
# min         2.000000   1.000000      38.082112   1.383000e+03
# ...

# %% [markdown]
# 1)Here we find that the mean is higher than median in most of the columns
#
# If the mean is higher than the median, the distribution is positively skewed.
#
# 2)the maximum and the 75% has a very wide range of difference
#
# From 1) and 2) we infer that we may have large outliers and skewness in some of the attributes

# %% [markdown]
# # 1)Aggregated Death case count for the state

# %% [markdown]
# # Exploratory data analysis for Target "Deaths"

# %% [markdown]
# ###### Univariate Analysis

# %%
#Displacement Plot
collist=df.columns.values
ncol=4
nrow=10
plt.figure(figsize=(30,30))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.distplot(df[collist[i]])

# %% [markdown]
# ###### KEY OBSERVATION

# %% [markdown]
# 1)The attributes "Mortality Rate","Hospitalization_Rate" have a normal distributions
#
# 2)Attributes which  shows Right skewed distribution includes
#
#         Long_
#
#         Confirmed
#
#         Deaths
#
#         Recovered
#
#         Active
#
#         FIPS
#
#         Incident_Rate
#
#         People_Tested
#
#         People_Hospitalized
#
#         ISO3
#
#         Testing_Rate
#
# It shows the value is Positively skewed
#
# 3)Attributes which  shows Left skewed distribution includes
#
#         UID
#
# It shows the value is negatively skewed

# %% [markdown]
# #### Bivariate analysis

# %%
df["People_Hospitalized"].sum()
# Out:
# 269359.99999999994

# %%
df["Deaths"].sum()
# Out:
# 93436

# %%
(269359.99-93436)/269359.99*100
# Out:
# 65.31184902405141

# %%
#Death_count vs People_Hospitalized
#Scatter_plot
sns.scatterplot(x="People_Hospitalized",y="Deaths",data=df)

# %% [markdown]
# ###### Observation:
#
# the scatter plot shows nearly 65% of people who were hospilalized were dead.

# %%
#Death_count vs Hospitalization_Rate
#Scatter_plot
sns.scatterplot(x="Hospitalization_Rate",y="Deaths",data=df)

# %% [markdown]
# ###### Observation:
#
# Death case was high when the Hospitalization Rate is around 14

# %% [markdown]
# # Correlation

# %%
cor=df.corr()
cor
# Out:
#                            Lat     Long_  Confirmed    Deaths  Recovered  \
# Lat                   1.000000 -0.570065   0.098689  0.110710   0.039246
# Long_                -0.570065  1.000000  -0.006640  0.016533  -0.042757
# Confirmed             0.098689 -0.006640   1.000000  0.982353   0.828503
# Deaths                0.110710  0.016533   0.982353  1.000000   0.833825
# Recovered             0.039246 -0.042757   0.828503  0.833825   1.000000
# Active                0.100299 -0.004159   0.985028  0.954112   0.729862
# FIPS                 -0.331101  0.433423  -0.091928 -0.061217  -0.011613
# Incident_Rate         0.210072  0.010608   0.710461  0.712258   0.547726
# People_Tested         0.024969 -0.105068   0.827191  0.741134   0.715043
# People_Hospitalized   0.034385  0.081917   0.875562  0.912220   0.761829
# Mortality_Rate       -0.189675  0.318569   0.375722  0.427860   0.337677
# UID                   0.718638 -0.714161   0.144630  0.112576   0.144639
# ...

# %%
#Visualization of Correlation
#usind Heatmap
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,12))
sns.heatmap((cor),annot=True)

# %% [markdown]
# ###### KEY OBSERVATION:

# %% [markdown]
# from the above result it is clear that some columns making positive correlation while some has negative correlation to the target variable

# %% [markdown]
# columns making positive correlation
#
# 1)Lat
#
# 2)Long_
#
# 3)Confirmed
#
# 4)Recovered
#
# 5)Active
#
# 6)Incident_Rate
#
# 7)People_Tested
#
# 8)People_Hospitalized
#
# 9)Mortality_Rate
#
# 10)UID
#
# 11)Testing_Rate
#
# 12)Hospitalization_Rate

# %% [markdown]
# columns making negative correlation
#
# 1)FIPS
#
# 2)ISO3

# %% [markdown]
# # DATA CLEANING

# %%
#Dropping columns which are not related
df_death=df.drop(columns=["FIPS","ISO3"])

# %% [markdown]
# ### Finding Outliers

# %%
#Plotting Outliers
collist=df.columns.values
ncol=30
nrow=15
plt.figure(figsize=(3*nrow,ncol))
for i in range (0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(df[collist[i]],color="red",orient="v")
    plt.tight_layout()

# %% [markdown]
# ###### observation:
#
# we find outliers in most of the columns

# %% [markdown]
# ### Treating Outliers

# %%
#Removing Outliers
#Z-score Techinique
from scipy.stats import zscore
z=np.abs(zscore(df_death))
z
# Out:
# array([[6.50765958e-01, 6.69458544e-02, 2.85381615e-01, 2.84233281e-01,
#         0.00000000e+00, 2.06705482e-01, 3.43912139e-01, 2.20415338e-01,
#         3.38495634e-01, 2.76365615e-01, 2.80054735e-01, 3.25028261e-01,
#         7.54201371e-01],
#        [2.81754213e+00, 1.42046033e+00, 5.23520486e-01, 4.07893159e-01,
#         6.60279061e-01, 5.05793104e-01, 8.73607444e-01, 6.49098787e-01,
#         9.04285788e-17, 1.00891084e+00, 2.80054781e-01, 5.90624593e-01,
#         1.84556160e-15],
#        [4.82248147e-01, 5.73803210e-01, 2.50482439e-01, 2.29890562e-01,
#         3.20884739e-01, 2.58041954e-01, 4.97788457e-01, 2.17101079e-01,
#         3.08766879e-01, 2.16021593e-01, 2.80054873e-01, 9.03916062e-01,
#         6.02735561e-01],
#        [3.34228004e-01, 1.79992718e-01, 4.36893730e-01, 3.84465408e-01,
#         3.13047220e-01, 4.81729133e-01, 5.95533889e-01, 4.49863019e-01,
#         4.33746963e-01, 1.18165632e+00, 2.80054918e-01, 4.12991039e-01,
#         9.47779164e-01],
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 4,  6, 11, 11, 31, 33, 33, 33, 33, 33, 33, 33, 36, 36, 41, 42, 49],
#       dtype=int64), array([ 7, 12,  1, 10,  6,  2,  3,  4,  5,  6,  7,  8,  1, 10, 10, 11, 10],
#       dtype=int64))

# %%
df_death.shape
# Out:
# (55, 13)

# %%
df_new1=df_death[(z<3).all(axis=1)]
df_new1.shape
# Out:
# (46, 13)

# %%
#Percentage loss
loss=(55-46)/55*100
loss
# Out:
# 16.363636363636363

# %% [markdown]
# The Outliers loss percentange is not max.so proceeding further

# %% [markdown]
# #### ploting skewness

# %%
df_new1.skew()
# Out:
# Lat                     0.276390
# Long_                  -1.452557
# Confirmed               1.916809
# Deaths                  2.182344
# Recovered               2.386170
# Active                  2.432932
# Incident_Rate           1.705832
# People_Tested           1.769735
# People_Hospitalized     0.321958
# Mortality_Rate          0.397815
# UID                     0.004318
# Testing_Rate            1.281475
# Hospitalization_Rate    0.163926
# dtype: float64

# %%
#Skewness treatment
#treating using log
threshold=0.55
import numpy as np
for i in df_new1.columns:
    if df_new1[i].skew()>0.55:
        df_new1[i]=np.log1p(df_new1[i])

# %%
df_new1.skew()
# Out:
# Lat                     0.276390
# Long_                  -1.452557
# Confirmed              -0.527957
# Deaths                 -0.340012
# Recovered              -0.357593
# Active                 -0.900792
# Incident_Rate          -0.241672
# People_Tested          -0.064450
# People_Hospitalized     0.321958
# Mortality_Rate          0.397815
# UID                     0.004318
# Testing_Rate            0.652936
# Hospitalization_Rate    0.163926
# dtype: float64

# %% [markdown]
# # Seperating Target Variable

# %%
x_l=df_new1.drop(["Deaths"],axis=1)
y_death=df_new1["Deaths"]

# %% [markdown]
# # Scaling Input Variable

# %%
# Algorithms requires all features to be on common scale. 
#using Standard Scaler
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_death=sc.fit_transform(x_l)
x_death
# Out:
# array([[-1.11896147,  0.4042127 ,  0.23301103,  0.61638151,  0.54785823,
#          0.01807697,  0.26578308, -0.7242782 , -0.11164617, -1.80575751,
#         -0.17663401, -0.72317238],
#        [ 3.50044599, -3.08061188, -2.29015949, -1.96854575, -2.35291607,
#         -2.05865208, -1.32063696,  0.65132238, -0.96523796, -1.74195962,
#          1.10234524,  0.11057927],
#        [-0.89451416, -0.90076704,  0.32929801,  0.08097365,  0.45314374,
#         -0.32822775,  0.27213935, -0.60346455,  0.46210364, -1.61436385,
#         -1.38434809, -0.55573054],
#        [-0.6973675 ,  0.11315671, -0.46208759,  0.09889325, -0.7060079 ,
#         -0.60693954, -0.30427158, -1.11136674, -1.1665281 , -1.55056597,
#         -0.33251677, -0.93716802],
#        [-0.04703316, -0.57516718,  0.63730078,  0.01057189,  0.73124604,
#          0.54275855,  0.030512  ,  0.27051512,  0.85142652, -1.35917232,
#         -1.3619256 ,  0.97377702],
# ...

# %% [markdown]
# # Preparing dataset for model training

# %% [markdown]
# #### splitting the testing and training data

# %%
#importing Libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x_death,y_death,test_size=.20,random_state=42)

# %%
x_train.shape
# Out:
# (36, 12)

# %%
x_test.shape
# Out:
# (10, 12)

# %%
y_train.shape
# Out:
# (36,)

# %%
y_test.shape
# Out:
# (10,)

# %%
#importing our model libraries
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
lr=LinearRegression()
ls=Lasso()
rd=Ridge()
en=ElasticNet()
from sklearn.svm import SVR
svr=SVR()
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor()
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()

# %%
#importing error Metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
#using Algorithms via for loop
model=[lr,svr,knn,ls,rd,en]
for m in model:
    m.fit(x_train,y_train)
    print("score of ",m,"is",m.score(x_train,y_train))
    predm=m.predict(x_test)
    print("r2_score is :",r2_score(y_test,predm))
    print("error")
    print("mean_absolute_error is :",mean_absolute_error(y_test,predm))
    print("mean_squared_error is :",mean_squared_error(y_test,predm))
    print("root mean_absolute_error is :",np.sqrt(mean_squared_error(y_test,predm)))
    
    print("**********************************************************")
    print("\n\n")
# Out:
# score of  LinearRegression() is 0.9967503440925304
# r2_score is : 0.9768056373848887
# error
# mean_absolute_error is : 0.12368197306387527
# mean_squared_error is : 0.027088409972742887
# root mean_absolute_error is : 0.16458557036612562
# **********************************************************
#
#
#
# score of  SVR() is 0.9342536044589822
# r2_score is : 0.8975604794621496
# error
# mean_absolute_error is : 0.3283910878876156
# mean_squared_error is : 0.11963785234316482
# root mean_absolute_error is : 0.3458870514245435
# **********************************************************
#
#
#
# score of  KNeighborsRegressor() is 0.9267271718316401
# r2_score is : 0.6961212895814834
# error
# mean_absolute_error is : 0.48831539100409127
# mean_squared_error is : 0.3548961972527864
# root mean_absolute_error is : 0.5957316486915786
# **********************************************************
#
#
#
# score of  Lasso() is 0.6649858285015693
# r2_score is : 0.4677784523112398
# error
# ...

# %%
#Cross_validate the model
from sklearn.model_selection import cross_val_score
#using Algorithms via for loop
model=[lr,svr,knn,ls,rd,en]
for m in model:
    m.fit(x_train,y_train)
    predm=m.predict(x_test)
    score=cross_val_score(m,x_death,y_death,cv=5,scoring="r2")
    print("score of",m,"is")
    print("r2_score is :",r2_score(y_test,predm))
    print("cross_val_score is :",score.mean())
    print("**********************************************************")
    print("\n\n")
# Out:
# score of LinearRegression() is
# r2_score is : 0.9768056373848887
# cross_val_score is : 0.9899073708139282
# **********************************************************
#
#
#
# score of SVR() is
# r2_score is : 0.8975604794621496
# cross_val_score is : 0.7177507914379374
# **********************************************************
#
#
#
# score of KNeighborsRegressor() is
# r2_score is : 0.6961212895814834
# cross_val_score is : 0.8528976780607712
# **********************************************************
#
#
#
# score of Lasso() is
# r2_score is : 0.4677784523112398
# cross_val_score is : 0.49362863278862645
# **********************************************************
#
#
#
# score of Ridge() is
# r2_score is : 0.9649395040020319
# cross_val_score is : 0.9893278215584601
# **********************************************************
#
#
#
# score of ElasticNet() is
# r2_score is : 0.6457440699888866
# cross_val_score is : 0.7354598915429322
# ...

# %% [markdown]
# Both Linear Regression and Ridge Regressor gives best Results.we go with Linear Regression.

# %% [markdown]
# # Ensemble Technique to boostup our score

# %%
#using Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
rf_pred=rf.predict(x_test)
print("score is",rf.score(x_train,y_train))
print("r2 score is",r2_score(y_test,rf_pred))
print("mean absolute error is : ",mean_absolute_error(y_test,rf_pred))
print("mean squared error is : ",mean_squared_error(y_test,rf_pred))
print("root mean absolute error is : ",np.sqrt(mean_absolute_error(y_test,rf_pred)))
# Out:
# score is 0.9882742738238286
# r2 score is 0.625487107996189
# mean absolute error is :  0.5030528211679328
# mean squared error is :  0.4373889865836323
# root mean absolute error is :  0.7092621667394454

# %%
#using AdaBoost
from sklearn.ensemble import AdaBoostRegressor
lasso=Lasso()
ada=AdaBoostRegressor(base_estimator=lasso,n_estimators=20,learning_rate=0.1,random_state=5)
ada.fit(x_train,y_train)
ada_pred=ada.predict(x_test)
ada_score=ada.score(x_train,y_train)
print("score is",ada_score)
print("r2 score is",r2_score(y_test,ada_pred))
print("mean absolute error is : ",mean_absolute_error(y_test,ada_pred))
print("mean squared error is : ",mean_squared_error(y_test,ada_pred))
print("root mean absolute error is : ",np.sqrt(mean_absolute_error(y_test,ada_pred)))
# Out:
# score is 0.7227582172751725
# r2 score is 0.5084219718099932
# mean absolute error is :  0.6196376319046888
# mean squared error is :  0.5741079150210384
# root mean absolute error is :  0.7871706497988151

# %% [markdown]
# ###### Observation:
#
# from above it is clear that the Linear model overfits the ensemble technique

# %%
#Linear Regression
#Final
lr=LinearRegression()
lr.fit(x_train,y_train)
lr_pred=lr.predict(x_test)
lr_score=lr.score(x_train,y_train)
print("score is",lr_score)
print("r2 score is",r2_score(y_test,lr_pred))
print("mean absolute error is : ",mean_absolute_error(y_test,lr_pred))
print("mean squared error is : ",mean_squared_error(y_test,lr_pred))
print("root mean absolute error is : ",np.sqrt(mean_absolute_error(y_test,lr_pred)))
# Out:
# score is 0.9967503440925304
# r2 score is 0.9768056373848887
# mean absolute error is :  0.12368197306387527
# mean squared error is :  0.027088409972742887
# root mean absolute error is :  0.35168447941851977

# %%
#plotting scatter plot between test and predicted data for Linear Regression
plt.scatter(y_test,lr_pred)
plt.title("scatter plot between test and predicted data")
plt.xlabel("y_test")
plt.ylabel("lr_pred")
# Out:
# Text(0, 0.5, 'lr_pred')

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(lr.predict(x_test))
df_con=pd.DataFrame({"original":a,"Predicted":predicted})
df_con.head(10)
# Out:
#    original  Predicted
# 0  4.510860   4.813492
# 1  4.934474   5.280557
# 2  5.934894   5.900237
# 3  6.177944   6.027202
# 4  6.011267   5.925417
# 5  6.981006   6.914616
# 6  7.170120   7.194406
# 7  7.531016   7.575599
# 8  7.437206   7.479240
# 9  4.682131   4.821693

# %% [markdown]
# # Saving model for target "Deaths"

# %%
import joblib
joblib.dump(lr,"covid19-death.obj")
# Out:
# ['covid19-death.obj']

# %% [markdown]
# # 2)Aggregated Recovered case count for the state

# %% [markdown]
# ###### Univariate Analysis

# %%
#Displacement Plot
collist=df.columns.values
ncol=14
nrow=10
plt.figure(figsize=(30,30))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.distplot(df[collist[i]])

# %% [markdown]
# ###### KEY OBSERVATION

# %% [markdown]
# 1)The attributes "Mortality Rate","Hospitalization_Rate" have a normal distributions
#
# 2)Attributes which  shows Right skewed distribution includes
#
#         Long_
#
#         Confirmed
#
#         Deaths
#
#         Recovered
#
#         Active
#
#         FIPS
#
#         Incident_Rate
#
#         People_Tested
#
#         People_Hospitalized
#
#         ISO3
#
#         Testing_Rate
#
# It shows the value is Positively skewed
#
# 3)Attributes which  shows Left skewed distribution includes
#
#         UID
#
# It shows the value is negatively skewed

# %% [markdown]
# ###### Bivariate Analysis

# %%
df["People_Hospitalized"].sum()
# Out:
# 269359.99999999994

# %%
df["Recovered"].sum()
# Out:
# 385408.5714285714

# %%
(269359.99-385408)/269359.99*100
# Out:
# -43.08286839481989

# %%
#Recovered vs People_Hospitalized
#Scatter_plot
sns.scatterplot(x="People_Hospitalized",y="Recovered",data=df)

# %% [markdown]
# ###### observation
#
# the scatter plot shows nearly 45% of people who were hospilalized were recoverd.

# %%
#Recovered vs confirmed
#Scatter_plot
sns.scatterplot(x="Confirmed",y="Recovered",data=df)

# %% [markdown]
# ###### observation
#
# confirmed Covid cases was around 100000 where only around 30000 were recovered

# %% [markdown]
# # Correlation

# %%
cor=df.corr()
cor
# Out:
#                            Lat     Long_  Confirmed    Deaths  Recovered  \
# Lat                   1.000000 -0.570065   0.098689  0.110710   0.039246
# Long_                -0.570065  1.000000  -0.006640  0.016533  -0.042757
# Confirmed             0.098689 -0.006640   1.000000  0.982353   0.828503
# Deaths                0.110710  0.016533   0.982353  1.000000   0.833825
# Recovered             0.039246 -0.042757   0.828503  0.833825   1.000000
# Active                0.100299 -0.004159   0.985028  0.954112   0.729862
# FIPS                 -0.331101  0.433423  -0.091928 -0.061217  -0.011613
# Incident_Rate         0.210072  0.010608   0.710461  0.712258   0.547726
# People_Tested         0.024969 -0.105068   0.827191  0.741134   0.715043
# People_Hospitalized   0.034385  0.081917   0.875562  0.912220   0.761829
# Mortality_Rate       -0.189675  0.318569   0.375722  0.427860   0.337677
# UID                   0.718638 -0.714161   0.144630  0.112576   0.144639
# ...

# %%
#Visualization of Correlation
#usind Heatmap
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,12))
sns.heatmap((cor),annot=True)

# %% [markdown]
# ##### KEY OBSERVATION:

# %% [markdown]
# from the above result it is clear that some columns making positive correlation while some has negative correlation to the target variable

# %% [markdown]
# columns making positive correlation
#
# 1)Lat
#
# 2)Long_
#
# 3)Confirmed
#
# 4)Recovered
#
# 5)Active
#
# 6)Incident_Rate
#
# 7)People_Tested
#
# 8)People_Hospitalized
#
# 9)Mortality_Rate
#
# 10)UID
#
# 11)Testing_Rate
#
# 12)Hospitalization_Rate

# %% [markdown]
# columns making negative correlation
#
# 1)FIPS
#
# 2)ISO3

# %% [markdown]
# # DATA CLEANING

# %%
#Dropping columns which are not related
df_recovery=df.drop(columns=["FIPS","ISO3"])

# %% [markdown]
# ### Finding Outliers

# %%
#Plotting Outliers
collist=df_recovery.columns.values
ncol=30
nrow=15
plt.figure(figsize=(3*nrow,ncol))
for i in range (0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(df_recovery[collist[i]],color="red",orient="v")
    plt.tight_layout()

# %% [markdown]
# we find outliers in most of the columns

# %% [markdown]
# ### Treating Outliers

# %%
#Removing Outliers
#Z-score Techinique
from scipy.stats import zscore
z1=np.abs(zscore(df_recovery))
z1
# Out:
# array([[6.50765958e-01, 6.69458544e-02, 2.85381615e-01, 2.84233281e-01,
#         0.00000000e+00, 2.06705482e-01, 3.43912139e-01, 2.20415338e-01,
#         3.38495634e-01, 2.76365615e-01, 2.80054735e-01, 3.25028261e-01,
#         7.54201371e-01],
#        [2.81754213e+00, 1.42046033e+00, 5.23520486e-01, 4.07893159e-01,
#         6.60279061e-01, 5.05793104e-01, 8.73607444e-01, 6.49098787e-01,
#         9.04285788e-17, 1.00891084e+00, 2.80054781e-01, 5.90624593e-01,
#         1.84556160e-15],
#        [4.82248147e-01, 5.73803210e-01, 2.50482439e-01, 2.29890562e-01,
#         3.20884739e-01, 2.58041954e-01, 4.97788457e-01, 2.17101079e-01,
#         3.08766879e-01, 2.16021593e-01, 2.80054873e-01, 9.03916062e-01,
#         6.02735561e-01],
#        [3.34228004e-01, 1.79992718e-01, 4.36893730e-01, 3.84465408e-01,
#         3.13047220e-01, 4.81729133e-01, 5.95533889e-01, 4.49863019e-01,
#         4.33746963e-01, 1.18165632e+00, 2.80054918e-01, 4.12991039e-01,
#         9.47779164e-01],
# ...

# %%
threshold=3
print(np.where(z1>3))
# Out:
# (array([ 4,  6, 11, 11, 31, 33, 33, 33, 33, 33, 33, 33, 36, 36, 41, 42, 49],
#       dtype=int64), array([ 7, 12,  1, 10,  6,  2,  3,  4,  5,  6,  7,  8,  1, 10, 10, 11, 10],
#       dtype=int64))

# %%
df_recovery.shape
# Out:
# (55, 13)

# %% [markdown]
# ###### Observation:
#
#     we can see if we remove outliers we may have a huge loss of data.so Outlier removing is not preferable

# %%
df_new2=df_recovery
df_new2
# Out:
#         Lat     Long_  Confirmed  Deaths     Recovered    Active  \
# 0   32.3182  -86.9023      13052     522   7007.428571   12530.0
# 1   61.3707 -152.4044        401      10    352.000000      39.0
# 3   33.7298 -111.4312      14906     747   3773.000000   10386.0
# 4   34.9697  -92.3731       5003     107   3852.000000    1044.0
# 5   36.1162 -119.6816      85997    3497   7007.428571   82500.0
# 6   39.0598 -105.3111      22797    1299   3478.000000   18020.0
# 7   41.5978  -72.7554      39017    3529   6264.000000   29224.0
# 8   39.3185  -75.5071       8194     310   3965.000000    3919.0
# 10  38.8974  -77.0268       7551     407   1059.000000    6085.0
# 11  27.7663  -81.6868      47471    2096   7007.428571   45375.0
# 12  33.0406  -83.6431      39801    1697   7007.428571   38104.0
# 14  13.4443  144.7937        154       5    125.000000      24.0
# 15  21.0943 -157.4983        643      17    578.000000      48.0
# ...

# %% [markdown]
# # Seperating Target Variable

# %%
x=df_new2.drop(["Recovered"],axis=1)
y_recovered=df_new2["Recovered"]

# %% [markdown]
# # Scaling Input Variable

# %%
# Algorithms requires all features to be on common scale. 
#using Standard Scaler
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_recovered=sc.fit_transform(x)
x_recovered
# Out:
# array([[-6.50765958e-01, -6.69458544e-02, -2.85381615e-01,
#         -2.84233281e-01, -2.06705482e-01, -3.43912139e-01,
#         -2.20415338e-01, -3.38495634e-01, -2.76365615e-01,
#          2.80054735e-01, -3.25028261e-01, -7.54201371e-01],
#        [ 2.81754213e+00, -1.42046033e+00, -5.23520486e-01,
#         -4.07893159e-01, -5.05793104e-01, -8.73607444e-01,
#         -6.49098787e-01,  9.04285788e-17, -1.00891084e+00,
#          2.80054781e-01,  5.90624593e-01, -1.84556160e-15],
#        [-4.82248147e-01, -5.73803210e-01, -2.50482439e-01,
#         -2.29890562e-01, -2.58041954e-01, -4.97788457e-01,
#         -2.17101079e-01, -3.08766879e-01,  2.16021593e-01,
#          2.80054873e-01, -9.03916062e-01, -6.02735561e-01],
#        [-3.34228004e-01, -1.79992718e-01, -4.36893730e-01,
#         -3.84465408e-01, -4.81729133e-01, -5.95533889e-01,
#         -4.49863019e-01, -4.33746963e-01, -1.18165632e+00,
#          2.80054918e-01, -4.12991039e-01, -9.47779164e-01],
# ...

# %% [markdown]
# # preparing dataset for model training

# %% [markdown]
# #### splitting the testing and training data

# %%
#importing Libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
x_train1,x_test1,y_train1,y_test1=train_test_split(x_recovered,y_recovered,test_size=.20,random_state=42)

# %%
x_train1.shape
# Out:
# (44, 12)

# %%
x_test1.shape
# Out:
# (11, 12)

# %%
y_train1.shape
# Out:
# (44,)

# %%
y_test1.shape
# Out:
# (11,)

# %%
#importing our model libraries
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
lr=LinearRegression()
ls=Lasso()
rd=Ridge()
en=ElasticNet()
from sklearn.svm import SVR
svr=SVR()
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor()
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()

# %%
#importing error Metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
#using Algorithms via for loop
model=[lr,svr,knn,ls,rd,en]
for m in model:
    m.fit(x_train1,y_train1)
    print("score of ",m,"is",m.score(x_train1,y_train1))
    predm=m.predict(x_test1)
    print("r2_score is :",r2_score(y_test1,predm))
    print("error")
    print("mean_absolute_error is :",mean_absolute_error(y_test1,predm))
    print("mean_squared_error is :",mean_squared_error(y_test1,predm))
    print("root mean_absolute_error is :",np.sqrt(mean_squared_error(y_test1,predm)))
    
    print("**********************************************************")
    print("\n\n")
# Out:
# score of  LinearRegression() is 0.9671153485715877
# r2_score is : 0.9067438576732745
# error
# mean_absolute_error is : 2238.774516680893
# mean_squared_error is : 7231007.175051658
# root mean_absolute_error is : 2689.053211643767
# **********************************************************
#
#
#
# score of  SVR() is -0.05824211006807789
# r2_score is : -0.0898676776645273
# error
# mean_absolute_error is : 5955.3443490587315
# mean_squared_error is : 84507473.72155216
# root mean_absolute_error is : 9192.794663297564
# **********************************************************
#
#
#
# score of  KNeighborsRegressor() is 0.3797218550349123
# r2_score is : 0.39199217858107993
# error
# mean_absolute_error is : 4301.9974025974025
# mean_squared_error is : 47144443.35220779
# root mean_absolute_error is : 6866.181133075925
# **********************************************************
#
#
#
# score of  Lasso() is 0.9671066132742518
# r2_score is : 0.9060225514323351
# error
# ...

# %% [markdown]
# ###### Observation
#
# Both Linear Regression and Lasso Regressor gives best Results.we go with Linear Regression.

# %% [markdown]
# # Ensemble Technique to boostup our score

# %%
#using Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train1,y_train1)
rf_pred=rf.predict(x_test1)
print("score is",rf.score(x_train1,y_train1))
print("r2 score is",r2_score(y_test1,rf_pred))
print("mean absolute error is : ",mean_absolute_error(y_test1,rf_pred))
print("mean squared error is : ",mean_squared_error(y_test1,rf_pred))
print("root mean absolute error is : ",np.sqrt(mean_absolute_error(y_test1,rf_pred)))
# Out:
# score is 0.8678139247071267
# r2 score is 0.5207603450002338
# mean absolute error is :  3814.3809090909085
# mean squared error is :  37159862.04674342
# root mean absolute error is :  61.76067445463099

# %%
#using AdaBoost
from sklearn.ensemble import AdaBoostRegressor
lasso=Lasso()
ada=AdaBoostRegressor(base_estimator=lasso,n_estimators=20,learning_rate=0.1,random_state=5)
ada.fit(x_train1,y_train1)
ada_pred=ada.predict(x_test1)
ada_score=ada.score(x_train1,y_train1)
print("score is",ada_score)
print("r2 score is",r2_score(y_test1,ada_pred))
print("mean absolute error is : ",mean_absolute_error(y_test1,ada_pred))
print("mean squared error is : ",mean_squared_error(y_test1,ada_pred))
print("root mean absolute error is : ",np.sqrt(mean_absolute_error(y_test1,ada_pred)))
# Out:
# score is 0.9742463386942232
# r2 score is 0.9306235342702895
# mean absolute error is :  1974.7336898736794
# mean squared error is :  5379396.026415891
# root mean absolute error is :  44.437975762557855

# %% [markdown]
# ###### Observation
#
# from above it is clear that the ensemble technique overfits the Linear model

# %% [markdown]
# ### Hypertuning

# %%
#parameters for AdaBoostRegressor 
print(ada.get_params().keys())
# Out:
# dict_keys(['base_estimator__alpha', 'base_estimator__copy_X', 'base_estimator__fit_intercept', 'base_estimator__max_iter', 'base_estimator__normalize', 'base_estimator__positive', 'base_estimator__precompute', 'base_estimator__random_state', 'base_estimator__selection', 'base_estimator__tol', 'base_estimator__warm_start', 'base_estimator', 'learning_rate', 'loss', 'n_estimators', 'random_state'])

# %%
#Hyper parameter Tuning
#RandomForestClassifier
#using GridSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostRegressor
parameters={"n_estimators" :[1,10,100,1000], "random_state": list(range(0,10))}
ada=AdaBoostRegressor()
clf=GridSearchCV(ada,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'n_estimators': 100, 'random_state': 0}

# %%
#applying parameters
#AdaBoost
from sklearn.ensemble import AdaBoostRegressor
lasso=Lasso()
ada=AdaBoostRegressor(base_estimator=lasso,n_estimators=100,learning_rate=0.1,random_state=0)
ada.fit(x_train1,y_train1)
ada_pred=ada.predict(x_test1)
ada_score=ada.score(x_train1,y_train1)
print("score is",ada_score)
print("r2 score is",r2_score(y_test1,ada_pred))
print("mean absolute error is : ",mean_absolute_error(y_test1,ada_pred))
print("mean squared error is : ",mean_squared_error(y_test1,ada_pred))
print("root mean absolute error is : ",np.sqrt(mean_absolute_error(y_test1,ada_pred)))
# Out:
# score is 0.9743349406833818
# r2 score is 0.9351194745257944
# mean absolute error is :  1965.8134413424807
# mean squared error is :  5030784.391460424
# root mean absolute error is :  44.33749475717455

# %%
#plotting scatter plot between test and predicted data for Linear Regression
plt.scatter(y_test,lr_pred)
plt.title("scatter plot between test and predicted data")
plt.xlabel("y_test1")
plt.ylabel("ada_pred")
# Out:
# Text(0, 0.5, 'ada_pred')

# %% [markdown]
# # Saving Model

# %%
import joblib
joblib.dump(ada,"covid19-recovered.obj")
# Out:
# ['covid19-recovered.obj']
